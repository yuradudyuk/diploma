# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
names_of_outfiles=['no2_for_matrix.txt','o3_for_matrix.txt','so2_for_matrix.txt','pm2p5_for_matrix.txt','pm10_for_matrix.txt','co_for_matrix.txt']
names=['temp_max_formatrix.txt','temp_min_formatrix.txt','humidity_formatrix.txt','opady_formatrix.txt','atmo_pressure_formatrix.txt','wind_speed_formatrix.txt']
col1= np.loadtxt(names_of_outfiles[0], delimiter='\n')
col2 = np.loadtxt(names_of_outfiles[1], delimiter='\n')
col3 = np.loadtxt(names_of_outfiles[2], delimiter='\n')
col4 = np.loadtxt(names_of_outfiles[3], delimiter='\n')
col5 = np.loadtxt(names_of_outfiles[4], delimiter='\n')
col6 = np.loadtxt(names_of_outfiles[5], delimiter='\n')
col7 = np.loadtxt(names[0], delimiter='\n')
col8 = np.loadtxt(names[1], delimiter='\n')
col9 = np.loadtxt(names[2], delimiter='\n')
col10 = np.loadtxt(names[3], delimiter='\n')
col11 = np.loadtxt(names[4], delimiter='\n')
col12 = np.loadtxt(names[5], delimiter='\n')

df = pd.DataFrame({'no2': col1, 'o3': col2,'so2':col3,'pm2.5':col4,'pm10': col5, 'co': col6,'t_max':col7,'t_min':col8,'hum': col9, 'opady': col10,'tysk':col11,'windsp':col12})
df.to_csv('dataframe_of_first_ model.csv')
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\YURADU~1\AppData\Local\Temp/ipykernel_10388/3164669702.py in <module>
# ----> 1 import xarray as xr
#       2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 names_of_outfiles=['no2_for_matrix.txt','o3_for_matrix.txt','so2_for_matrix.txt','pm2p5_for_matrix.txt','pm10_for_matrix.txt','co_for_matrix.txt']
#
# ~\anaconda3\lib\site-packages\xarray\__init__.py in <module>
# ----> 1 from . import testing, tutorial, ufuncs
#       2 from .backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#       5     open_dataarray,
#
# ~\anaconda3\lib\site-packages\xarray\testing.py in <module>
#       7
#       8 from xarray.core import duck_array_ops, formatting, utils
# ----> 9 from xarray.core.dataarray import DataArray
# ...

# %%
cor=df.corr()
# Out:
#              no2        o3       so2     pm2.5      pm10        co
# no2     1.000000 -0.652189  0.669933  0.645145  0.663335  0.640349
# o3     -0.652189  1.000000 -0.069782 -0.338577 -0.328313 -0.573280
# so2     0.669933 -0.069782  1.000000  0.764372  0.789638  0.393902
# pm2.5   0.645145 -0.338577  0.764372  1.000000  0.993990  0.555339
# pm10    0.663335 -0.328313  0.789638  0.993990  1.000000  0.559867
# co      0.640349 -0.573280  0.393902  0.555339  0.559867  1.000000
# t_max  -0.453684  0.402400 -0.140488 -0.087298 -0.120500 -0.699130
# t_min  -0.408656  0.221973 -0.302353 -0.238109 -0.280580 -0.710264
# hum     0.568684 -0.755841  0.110883  0.373329  0.352546  0.529881
# opady  -0.094644 -0.183696 -0.284116 -0.183204 -0.222275 -0.236830
# tysk    0.206547 -0.128226  0.128923  0.261734  0.279867  0.195609
# windsp  0.034346  0.311400  0.234733 -0.096826 -0.071685 -0.070941

# %%
cor_ = df.corr () ['co']
cor_
# Out:
# no2       0.807141
# o3       -0.570936
# so2       0.701152
# pm2.5     0.762946
# pm10      0.679079
# co        1.000000
# t_max    -0.759588
# t_min    -0.764480
# hum       0.560179
# opady    -0.314428
# tysk      0.197018
# windsp    0.050941
# Name: co, dtype: float64

# %%
dff=pd.read_csv('dataframe_of_first_ model.csv',delimiter=',',index_col=0 )
dff
# Out:
#          no2         o3       so2      pm2.5       pm10          co  \
# 0   3.783875  49.345239  1.917797   8.031209   9.464757  195.043783
# 1   3.836256  54.881348  2.443517  10.640936  12.686302  194.041806
# 2   3.776707  59.521372  2.019546   9.903540  12.192924  194.684164
# 3   4.072212  60.743476  3.560883  18.353051  21.905664  218.238623
# 4   4.161248  54.715312  2.169823  16.485047  20.540913  215.664741
# ..       ...        ...       ...        ...        ...         ...
# 87  2.440870  69.778423  1.555527   7.581488   9.272971  138.705194
# 88  2.474146  66.731147  1.539976   7.226729   9.757848  136.916692
# 89  1.873383  67.046069  1.213483   7.028793   8.978765  141.783249
# 90  1.731858  63.695421  0.955741   5.393526   5.977667  146.129706
# 91  1.734039  60.847541  1.143347   5.120509   5.638763  136.934553
#
#         t_max      t_min        hum     opady        tysk    windsp
# 0    3.428095  -3.116810  89.428643  0.892929  100.233405  2.278095
# ...
